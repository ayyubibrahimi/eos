# %%
## what effect does time have on location, district, race, age

# %%
import pandas as pd
from lib import standardize_item_numbers

def clean():
    dfa = pd.read_csv("../data/police_reports/electronic_police_report_2018_2022.csv")
    dfa = dfa.pipe(standardize_item_numbers, ["item_number"])

    dfb = pd.read_csv("../data/real_time_crime_center/rtcc.csv")
    dfb["footage_requested"] = "1"
    dfb = dfb.pipe(standardize_item_numbers, ["item_number"])

    df = pd.merge(dfa, dfb, on="item_number", how="outer")
    return df

# %%
df = clean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2948\2009617884.py:5: DtypeWarning: Columns (14,20,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfa = pd.read_csv("../data/police_reports/electronic_police_report_2018_2022.csv")

# %%
df = df.drop_duplicates(subset=["offender_race", "offender_gender", "offender_age", "item_number"])

# %%
not_requested_df = df[~((df.footage_requested == "1"))]
df = df[((df.footage_requested == "1"))]

df.shape
# Out:
# (19265, 28)

# %%
datetimes = (df.occurred_date_time.str.replace(r"(\w{4})-(\w{1,2})-(\w{1,2})", r"\2/\3/\1").str.extract(r"(\w{2}):(\w{2}):?(\w{2})?"))
df.loc[:, "occurred_datetime"] = datetimes[0]
df.occurred_datetime.value_counts()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2948\43808543.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   datetimes = (df.occurred_date_time.str.replace(r"(\w{4})-(\w{1,2})-(\w{1,2})", r"\2/\3/\1").str.extract(r"(\w{2}):(\w{2}):?(\w{2})?"))
# 23    487
# 21    454
# 20    448
# 19    431
# 01    428
# 17    423
# 18    412
# 22    403
# 16    381
# 00    370
# 15    370
# 02    369
# 03    337
# 11    336
# 14    330
# 12    303
# 10    286
# 04    264
# 13    259
# 05    159
# 09    159
# 08    151
# 06    138
# 07    121
# Name: occurred_datetime, dtype: int64

# %%
df.location.count().sum()
# Out:
# 8488

# %%
df.shape
# Out:
# (19265, 29)

# %%
requested = df[df.footage_requested.isin(["1"])]

# %%
requested.year.value_counts()
# Out:
# 2021.0    2095
# 2020.0    1989
# 2022.0    1770
# 2019.0    1605
# 2018.0    1029
# Name: year, dtype: int64

# %%
requested.groupby("year").disposition.value_counts()
# Out:
# year    disposition
# 2018.0  OPEN            612
#         CLOSED          396
#         UNFOUNDED        21
# 2019.0  OPEN            938
#         CLOSED          637
#         UNFOUNDED        30
# 2020.0  OPEN           1423
#         CLOSED          530
#         UNFOUNDED        36
# 2021.0  OPEN           1545
#         CLOSED          499
#         UNFOUNDED        51
# 2022.0  OPEN           1276
#         CLOSED          472
#         UNFOUNDED        22
# Name: disposition, dtype: int64

# %%
not_requested_df.groupby("year").disposition.value_counts()
# Out:
# year    disposition
# 2018.0  OPEN           51455
#         CLOSED         21322
#         UNFOUNDED        375
# 2019.0  OPEN           51235
#         CLOSED         18231
#         UNFOUNDED        458
# 2020.0  OPEN           46814
#         CLOSED         10623
#         UNFOUNDED        368
# 2021.0  OPEN           47268
#         CLOSED          9396
#         UNFOUNDED        561
# 2022.0  OPEN           40355
#         CLOSED          7224
#         UNFOUNDED        437
# Name: disposition, dtype: int64

# %%
requested.groupby("year").disposition.value_counts(normalize=True)
# Out:
# year    disposition
# 2018.0  OPEN           0.594752
#         CLOSED         0.384840
#         UNFOUNDED      0.020408
# 2019.0  OPEN           0.584424
#         CLOSED         0.396885
#         UNFOUNDED      0.018692
# 2020.0  OPEN           0.715435
#         CLOSED         0.266466
#         UNFOUNDED      0.018100
# 2021.0  OPEN           0.737470
#         CLOSED         0.238186
#         UNFOUNDED      0.024344
# 2022.0  OPEN           0.720904
#         CLOSED         0.266667
#         UNFOUNDED      0.012429
# Name: disposition, dtype: float64

# %%
not_requested_df.groupby("year").disposition.value_counts(normalize=True)

"""
2018: 59% open when requested vs 70 when not requested
2019: 58% vs 73%
2020: 71% vs 80
73 vs 82
72 vs 84
"""
# Out:
# year    disposition
# 2018.0  OPEN           0.703398
#         CLOSED         0.291475
#         UNFOUNDED      0.005126
# 2019.0  OPEN           0.732724
#         CLOSED         0.260726
#         UNFOUNDED      0.006550
# 2020.0  OPEN           0.809861
#         CLOSED         0.183773
#         UNFOUNDED      0.006366
# 2021.0  OPEN           0.826003
#         CLOSED         0.164194
#         UNFOUNDED      0.009803
# 2022.0  OPEN           0.840449
#         CLOSED         0.150450
#         UNFOUNDED      0.009101
# Name: disposition, dtype: float64

# %%
# r_ct = requested.groupby("year").disposition.value_counts().to_excel("../data/real_time_crime_center/requested_by_year_ct.xlsx")

# %%
# r_pct = requested.groupby("year").disposition.value_counts(normalize=True).to_excel("../data/real_time_crime_center/requested_by_year_pct.xlsx")

# %%
not_requested = df[~((df.footage_requested == "1.0"))]

# %%
not_requested.groupby("year").disposition.value_counts()
# Out:
# year    disposition
# 2018.0  OPEN            612
#         CLOSED          396
#         UNFOUNDED        21
# 2019.0  OPEN            938
#         CLOSED          637
#         UNFOUNDED        30
# 2020.0  OPEN           1423
#         CLOSED          530
#         UNFOUNDED        36
# 2021.0  OPEN           1545
#         CLOSED          499
#         UNFOUNDED        51
# 2022.0  OPEN           1276
#         CLOSED          472
#         UNFOUNDED        22
# Name: disposition, dtype: int64

# %%
not_requested.groupby("year").disposition.value_counts(normalize=True)
# Out:
# year    disposition
# 2018.0  OPEN           0.594752
#         CLOSED         0.384840
#         UNFOUNDED      0.020408
# 2019.0  OPEN           0.584424
#         CLOSED         0.396885
#         UNFOUNDED      0.018692
# 2020.0  OPEN           0.715435
#         CLOSED         0.266466
#         UNFOUNDED      0.018100
# 2021.0  OPEN           0.737470
#         CLOSED         0.238186
#         UNFOUNDED      0.024344
# 2022.0  OPEN           0.720904
#         CLOSED         0.266667
#         UNFOUNDED      0.012429
# Name: disposition, dtype: float64

# %%
r_ct = pd.DataFrame(not_requested.groupby("year").disposition.value_counts())
r_ct  = r_ct.rename(columns={r_ct.columns[0]: "requested_ct"})
r_ct = r_ct.reset_index()

r_pct = pd.DataFrame(not_requested.groupby("year").disposition.value_counts(normalize=True))
r_pct  = r_pct.rename(columns={r_pct.columns[0]: "requested_pct"})
r_pct = r_pct.reset_index()

nr_ct = pd.DataFrame(not_requested.groupby("year").disposition.value_counts())
nr_ct  = nr_ct.rename(columns={nr_ct.columns[0]: "not_requested_ct"})
nr_ct = nr_ct.reset_index()

nr_pct = pd.DataFrame(not_requested.groupby("year").disposition.value_counts(normalize=True))
nr_pct  = nr_pct.rename(columns={nr_pct.columns[0]: "not_requested_pct"})
nr_pct = nr_pct.reset_index()

# %%
dfs = pd.concat([nr_pct, nr_ct, r_pct, r_ct])

# %%
dfs
# Out:
#       year disposition  not_requested_pct  not_requested_ct  requested_pct  \
# 0   2018.0        OPEN           0.594752               NaN            NaN
# 1   2018.0      CLOSED           0.384840               NaN            NaN
# 2   2018.0   UNFOUNDED           0.020408               NaN            NaN
# 3   2019.0        OPEN           0.584424               NaN            NaN
# 4   2019.0      CLOSED           0.396885               NaN            NaN
# 5   2019.0   UNFOUNDED           0.018692               NaN            NaN
# 6   2020.0        OPEN           0.715435               NaN            NaN
# 7   2020.0      CLOSED           0.266466               NaN            NaN
# 8   2020.0   UNFOUNDED           0.018100               NaN            NaN
# 9   2021.0        OPEN           0.737470               NaN            NaN
# 10  2021.0      CLOSED           0.238186               NaN            NaN
# 11  2021.0   UNFOUNDED           0.024344               NaN            NaN
# 12  2022.0        OPEN           0.720904               NaN            NaN
# 13  2022.0      CLOSED           0.266667               NaN            NaN
# 14  2022.0   UNFOUNDED           0.012429               NaN            NaN
# 0   2018.0        OPEN                NaN             612.0            NaN
# 1   2018.0      CLOSED                NaN             396.0            NaN
# 2   2018.0   UNFOUNDED                NaN              21.0            NaN
# 3   2019.0        OPEN                NaN             938.0            NaN
# 4   2019.0      CLOSED                NaN             637.0            NaN
# 5   2019.0   UNFOUNDED                NaN              30.0            NaN
# 6   2020.0        OPEN                NaN            1423.0            NaN
# 7   2020.0      CLOSED                NaN             530.0            NaN
# 8   2020.0   UNFOUNDED                NaN              36.0            NaN
# 9   2021.0        OPEN                NaN            1545.0            NaN
# 10  2021.0      CLOSED                NaN             499.0            NaN
# 11  2021.0   UNFOUNDED                NaN              51.0            NaN
# 12  2022.0        OPEN                NaN            1276.0            NaN
# 13  2022.0      CLOSED                NaN             472.0            NaN
# 14  2022.0   UNFOUNDED                NaN              22.0            NaN
# 0   2018.0        OPEN                NaN               NaN       0.594752
# 1   2018.0      CLOSED                NaN               NaN       0.384840
# 2   2018.0   UNFOUNDED                NaN               NaN       0.020408
# 3   2019.0        OPEN                NaN               NaN       0.584424
# 4   2019.0      CLOSED                NaN               NaN       0.396885
# 5   2019.0   UNFOUNDED                NaN               NaN       0.018692
# 6   2020.0        OPEN                NaN               NaN       0.715435
# 7   2020.0      CLOSED                NaN               NaN       0.266466
# 8   2020.0   UNFOUNDED                NaN               NaN       0.018100
# 9   2021.0        OPEN                NaN               NaN       0.737470
# 10  2021.0      CLOSED                NaN               NaN       0.238186
# 11  2021.0   UNFOUNDED                NaN               NaN       0.024344
# 12  2022.0        OPEN                NaN               NaN       0.720904
# 13  2022.0      CLOSED                NaN               NaN       0.266667
# 14  2022.0   UNFOUNDED                NaN               NaN       0.012429
# 0   2018.0        OPEN                NaN               NaN            NaN
# 1   2018.0      CLOSED                NaN               NaN            NaN
# 2   2018.0   UNFOUNDED                NaN               NaN            NaN
# 3   2019.0        OPEN                NaN               NaN            NaN
# 4   2019.0      CLOSED                NaN               NaN            NaN
# 5   2019.0   UNFOUNDED                NaN               NaN            NaN
# 6   2020.0        OPEN                NaN               NaN            NaN
# 7   2020.0      CLOSED                NaN               NaN            NaN
# 8   2020.0   UNFOUNDED                NaN               NaN            NaN
# 9   2021.0        OPEN                NaN               NaN            NaN
# 10  2021.0      CLOSED                NaN               NaN            NaN
# 11  2021.0   UNFOUNDED                NaN               NaN            NaN
# 12  2022.0        OPEN                NaN               NaN            NaN
# 13  2022.0      CLOSED                NaN               NaN            NaN
# 14  2022.0   UNFOUNDED                NaN               NaN            NaN
#
#     requested_ct
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 0          612.0
# 1          396.0
# 2           21.0
# 3          938.0
# 4          637.0
# 5           30.0
# 6         1423.0
# 7          530.0
# 8           36.0
# 9         1545.0
# 10         499.0
# 11          51.0
# 12        1276.0
# 13         472.0
# 14          22.0

# %%
# df.to_excel("../data/real_time_crime_center/requests_per_year_2018_present.xlsx")
