# %%
import pandas as pd

# %%
dfa = pd.read_csv("../data/real_time_crime_center/rtcc_dump_2022.csv")

dfb = pd.read_csv("../data/real_time_crime_center/electronic_police_report_dump_2022.csv")

# %%
dfb
# Out:
#       item_number  District                     Location Disposition  \
# 0      C-00811-22         4  Bodenger Bd & Mardi Gras Bd      CLOSED
# 1      G-01318-22         7             043XX Dodt Av #3        OPEN
# 2      F-08049-22         7             044XX Francis Dr        OPEN
# 3      G-01211-22         5              006XX Reynes St        OPEN
# 4      G-01290-22         6     Carondelet St & Erato St        OPEN
# ...           ...       ...                          ...         ...
# 93003  J-09114-22         7      066XX N I-10 Service Rd        OPEN
# 93004  J-08958-22         5            021XX Painters St        OPEN
# 93005  J-08958-22         5            021XX Painters St        OPEN
# 93006  J-09180-22         4              029XX Sabine St        OPEN
# 93007  I-15146-22         1             022XX Poydras St      CLOSED
#
#       Signal_Type      Signal_Description Occurred_Date_Time Charge_Code  \
# ...

# %%
df = pd.merge(dfa, dfb, on="item_number")
df
df.to_csv("../data/real_time_crime_center/rtcc_dump_2022_merged_w_police_reports_2022.csv", index=False)

# %%
df.columns
# Out:
# Index(['item_number', 'Signal Code', 'Upon Researching the above item :',
#        'District', 'Location', 'Disposition', 'Signal_Type',
#        'Signal_Description', 'Occurred_Date_Time', 'Charge_Code',
#        'Charge_Description', 'Offender_Number', 'OffenderID', 'OffenderStatus',
#        'Offender_Race', 'Offender_Gender', 'Offender_Age', 'Victim_Number',
#        'PersonType', 'Victim_Race', 'Victim_Gender', 'Victim_Age',
#        'Victim_Fatal_Status', 'Hate Crime', 'Report Type'],
#       dtype='object')
